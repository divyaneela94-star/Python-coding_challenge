# %% [markdown]
# <a href="https://colab.research.google.com/github/divyaneela94-star/Python-coding_challenge/blob/main/Student_Exam_Score_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *** Student Exam Score Report***

# %%
import random

# %%
# 1. Create a list of 10 random exam scores (0–100) using list comprehension
scores = [random.randint(0, 100) for _ in range(10)]
print("Exam Scores:", scores)
# Out:
# Exam Scores: [100, 60, 85, 87, 77, 22, 19, 44, 89, 21]

# %%
# 2. Display each score with its index using enumerate
print("\nIndexed Scores:")
for index, score in enumerate(scores):
    print(f"{index}: {score}")
# Out:
# Indexed Scores:
# 0: 100
# 1: 60
# 2: 85
# 3: 87
# 4: 77
# 5: 22
# 6: 19
# 7: 44
# 8: 89
# 9: 21

# %%
# 3. Find all scores greater than 75
high_scores = [s for s in scores if s > 75]
print("\nScores above 75:", high_scores)
# Out:
# Scores above 75: [100, 85, 87, 77, 89]

# %%
# 4. Calculate and display the average score
average_score = sum(scores) / len(scores)
print("\nAverage Score:", round(average_score, 2))
# Out:
# Average Score: 60.4
