# %% [markdown]
# <a href="https://colab.research.google.com/github/divyaneela94-star/Python-coding_challenge/blob/main/Student_Profile_Creator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Student Profile Creator
#
# ---

# %%
name="Suresh"
name1="Mani"
name2="Aanandh"
name3="Balu"
name4="Kalai"
age=17
age1=18
age2=16
age3=19
age4=15
subject="Maths"
subject1="Science"
subject2="English"
subject3="ComputerScience"
print("-----------------------------------------------------------")
print("                  STUDENT'S INFORMATION                ")
print("-----------------------------------------------------------")
print("  Student'S Name  /  Age  /  Favourite Subjects            ")
print("                                                           ")
print(" 1.  ",name,"          ",age,"      ",subject)
print(" 2.  ",name1,"         ",age1,"     ",subject1)
print(" 3.  ",name2,"         ",age2,"     ",subject2)
print(" 4.  ",name3,"         ",age3,"     ",subject3)
print(" 5.  ",name4,"         ",age4,"     ",subject1)
print("-----------------------------------------------------------")

print("  Updated List of Subjects:")
print("-----------------------------")
print("1.Maths")
print("2.Science")
print("3.English")
print("4.ComputerScience")
# Out:
# -----------------------------------------------------------
#                   STUDENT'S INFORMATION
# -----------------------------------------------------------
#   Student'S Name  /  Age  /  Favourite Subjects
#
#  1.   Suresh            17        Maths
#  2.   Mani           18       Science
#  3.   Aanandh           16       English
#  4.   Balu           19       ComputerScience
#  5.   Kalai           15       Science
# -----------------------------------------------------------
#   Updated List of Subjects:
# -----------------------------
# 1.Maths
# 2.Science
# 3.English
# 4.ComputerScience
